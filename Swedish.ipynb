# %%
import random

# %%
dictionary2 = {'between': 'mellan',
 'use': 'andvander',
 'old': 'gammal',
 'clean': 'ren',
 'support': 'stottar',
 'important': 'viktig',
 'whole': 'hel',
 'different': 'olik',
 'last': 'sist',
 'necessary': 'nodvandig',
 'strange': 'konstiga',
 'expensive': 'dyr',
 'empty': 'tom',
 'serious': 'allvarlig',
 'again': 'igen',
 'sometimes': 'ibland',
 'never': 'aldrig',
 'usually': 'vanligtvis',
 'try': 'forsoker',
 'maybe': 'kanske',
 'parents': 'foralder',
 'corner': 'horn',
 'street': 'gata',
 'bed': 'seng',
 'large': 'stor',
 'wash': 'tvattar',
 'give': 'ger',
 'take': 'tar',
 'kitchen': 'kok',
 'public': 'allmanheten',
 'friends': 'vanner',
 'baby': 'spadbarn',
 'enemy': 'fiende',
 'application': 'ansokning',
 'already': 'redan',
 'difficult': 'svar',
 'arrives': 'kommer fram',
 'enjoys': 'trivs',
 'remember': 'minns',
 'brings': 'tar med...',
 'do you agree with': 'haller du med',
 'finally': 'antligen',
 'our': 'vår',
 'your': 'din',
 'their': 'deras',
 'her': 'hennes',}

# %%
dictionary4 = {
 'train': 'tag',
 'drive': 'kör',
 'visit': 'besök',
 'stop': 'slutar',
 'turns': 'svanger',
 'learn': 'lar',
 'actually': 'faktiskt',
 'even though': 'trots',
 'exercise': 'ovning',
 'chapter': 'kapitel',
 'difficulty': 'svarighet',
 'explanation': 'forklaring',
 'begin': 'borjar',
 'what does it mean': 'vat betyder det?',
 'later': 'senare',
'actually': 'faktiskt',
 'even though': 'trots',
 'exercise': 'ovning',
 'chapter': 'kapitel',
 'meets': 'möter',
 'cuts': 'klipper',
 'contains': 'innehaller',
 'puts': 'lagger',
 'feel': 'mår',
 'becomes': 'blir',
 'drops, lose': 'tappar',
 'misses': 'missar',
 'fills': 'fyller',
 'books': 'bokar',
 'builds': 'bygger',
 'teaches': 'undervisar',
 'leaves': 'lamnar',
 'together': 'tillsammans',}

# %%
dictionary5= { 'application': 'ansokning',
 'already': 'redan',
 'difficult': 'svar',
 'arrives': 'kommer fram',
 'enjoys': 'trivs',
 'remember': 'minns',
 'brings': 'tar med...',
 'do you agree with': 'haller du med',
 'finally': 'antligen',
 'finally': 'antligen',
 'our': 'vår',
 'your': 'din',
 'their': 'deras',
 'her': 'hennes', 'hates': 'hatar',
 'really': 'verkligen',
 'assumes': 'antar',
 'functions': 'fungerar',
 'share': 'delar',
 'closes': 'stanga',
 'until': 'tills','kept': 'behöll',
 'returned': 'kom tillbaka',
 'looks at': 'tittar pa',
 'show up, appear': 'dyka upp',
 'seems': 'verkar',
 'knew': 'visste',
 'said': 'sade',
 'tells': 'berättar',
 'in order to': 'for att',
 'decide': 'bestamma',
 'clearly': 'tydligt',
 'believe': 'tror',
 'except': 'utom',
 'be': 'vara'}

# %%
dictionary3 = {'stay': 'stannar',
 'money': 'pengar',
 'tired': 'trott',
 'wash': 'tvattar',
 'pretty': 'ganska',
 'still': 'fortfarande',
 'only': 'bara',
 'beautiful': 'vacker',
 'lady': 'dam',
 'relationship': 'forhallande',
 'handsome': 'snygg',
 'anyway': 'anda',
 '20': 'tjugo',
 '10': 'tio',
 '2': 'två',
 'number': 'antal',
 'nothing': 'ingenting',
 'something': 'nagot',
 'lookimg for smth': 'letar efter',
 'everything': 'allting',
 'everday': 'varje dag',
 'nobodye': 'ingen',
 'either': 'antingen',
 'neither': 'ingendera',
 'themselves': 'själva',
 'choose': 'valjer',
 'travels': 'reser',
 'car': 'bil',
 'train': 'tag',
 'airplane': 'flygplan',
 'drive': 'kör',
 'visit': 'besök',
 'stop': 'slutar',
 'turns': 'svanger',
 'learn': 'lar',
 'hates': 'hatar',
 'really': 'verkligen',
 'assumes': 'antar',
 'functions': 'fungerar',
 'share': 'delar',
 'closes': 'stanga'}

# %%
dictionary = {'word': 'ord',
 'My name is ': 'jag heter',
 'I speak ': 'jag pratar',
 'What is your name?': 'vad heter du?',
 'How old are you?': 'hur gammal ar du?',
 'I come from': 'jag kommer ifran',
 'and you?': 'och du?',
 'Where are you from?': 'varifran kommer du?',
 'Where ardo you live?': 'var bor du?',
 'I speak a little English': 'jag pratar lite Engelska',
 'he': 'han',
 'she': 'hon',
 'it': 'den, det',
 'we': 'vi',
 'you (plural)': 'ni',
 'They': 'de',
 'girl': 'flicka',
 'woman': 'kvinna',
 'the man': 'mannen',
 'the woman': 'kvinnan',
 'boy': 'pojke',
 'drink': 'dricker',
 'water': 'vatten',
 'newspaper': 'tidning',
 'read': 'laser',
 'milk': 'mjolk',
 'sandwich': 'smorgas',
 'child': 'barn',
 'book': 'bok',
 'menu': 'meny',
 'letter': 'brev',
 'have': 'har',
 'thank you so much': 'tack sa mycket',
 'love': 'alskar',
 'like': 'tycker om',
 'speak': 'talar',
 'not': 'inte',
 'think': 'tycker',
 'chicken': 'kyckling',
 'food': 'mat',
 'cheese': 'ost',
 'breakfast': 'frukost',
 'You are welcome': 'Versagod',
 'I am sorry': 'Ursakta',
 'see': 'ser',
 'animal': 'djur',
 'sleep': 'sover',
 'pay': 'betalar',
 'him': 'honom',
 'jump': 'hoppar',
 'meat': 'kottet',
 'swim': 'simmar',
 'buy': 'koper',
 'want': 'vill ha',
 'find': 'hittar',
 'play': 'leker',
 'their': 'sina',
 'trousers': 'byxor',
 'her': 'sin',
 'yellow': 'gula',
 'brown': 'brun',
 'white': 'vita',
 'gray': 'gra'}

# %%
len(dictionary)+ len(dictionary2)+len(dictionary3)+len(dictionary4)
# Out:
# 179

# %%
def yeni(sozzluk):
    key = input("Yeni kelime girin, ingilizce").lower()
    value = input("Isveççe karsiligini girin").lower()
    sozzluk[key]= value

# %%
dogru = ["Afferin koçum", " bravo", "helal be", "olacak olacak", "kim tutar seni", "Aslaaaaaaan"]
yanlis=["Sacma sapan cevaplar bunlar", "Yav he he", "Bak yanlis yapiyorsun", "git bastan calis"]
def sozluk(kemal):
    sira = 0
    score = 0
    for kelime in kemal:
        sira = sira + 1
        soru = random.choice(list(kemal.keys()))
        cevap = input(soru).lower()
        if sira <= 15:
             if cevap == kemal.get(soru):
                print(random.choice(dogru))
                score = score + 1
             else:
                print(random.choice(yanlis))
                print(kemal.get(soru))
        else:
            return score
    print(score)

# %%
sozluk(dictionary5)
# Out:
# do you agree withhaller du med
#  bravo
# keptbeholl
# Yav he he
# behöll
# finallyantligen
# helal be
# in order tofor att
# olacak olacak
# in order tofor att
# helal be
# keptbeholl
# git bastan calis
# behöll
# clearlytydligt
# Afferin koçum
# alreadyredan
# Afferin koçum
# returnedkom tillbaka
# kim tutar seni
# hateshatar
# Aslaaaaaaan
# bringstar med
# git bastan calis
# tar med...
# herhennes
# Aslaaaaaaan
# alreadyredan
# helal be
# in order tofor att
# Aslaaaaaaan
# show up, appeardyka upp
# Afferin koçum
# looks attittar pa
# 12

# %%
dictionary2
# Out:
# {'between': 'mellan',
#  'use': 'andvander',
#  'old': 'gammal',
#  'clean': 'ren',
#  'support': 'stottar',
#  'important': 'viktig',
#  'whole': 'hel',
#  'different': 'olik',
#  'last': 'sist',
#  'necessary': 'nodvandig',
#  'strange': 'konstiga',
#  'expensive': 'dyr',
#  'empty': 'tom',
#  'serious': 'allvarlig',
#  'again': 'igen',
#  'sometimes': 'ibland',
#  'never': 'aldrig',
#  'usually': 'vanligtvis',
#  'try': 'forsoker',
#  'maybe': 'kanske',
#  'parents': 'foralder',
#  'corner': 'horn',
#  'street': 'gata',
#  'bed': 'seng',
#  'large': 'stor',
#  'wash': 'tvattar',
#  'give': 'ger',
#  'take': 'tar',
#  'kitchen': 'kok',
#  'public': 'allmanheten',
#  'friends': 'vanner',
#  'baby': 'spadbarn',
#  'enemy': 'fiende',
#  'application': 'ansokning',
#  'already': 'redan',
#  'difficult': 'svar',
#  'arrives': 'kommer fram',
#  'enjoys': 'trivs',
#  'remember': 'minns',
#  'brings': 'tar med...',
#  'do you agree with': 'haller du med',
#  'finally': 'antligen',
# ...

# %%
dictionary.pop("like")
# Out:
# 'tycker om'

# %%
dictionary
# Out:
# {'word': 'ord',
#  'My name is ': 'jag heter',
#  'I speak ': 'jag pratar',
#  'What is your name?': 'vad heter du?',
#  'How old are you?': 'hur gammal ar du?',
#  'I come from': 'jag kommer ifran',
#  'and you?': 'och du?',
#  'Where are you from?': 'varifran kommer du?',
#  'Where ardo you live?': 'var bor du?',
#  'I speak a little English': 'jag pratar lite Engelska',
#  'he': 'han',
#  'she': 'hon',
#  'it': 'den, det',
#  'we': 'vi',
#  'you (plural)': 'ni',
#  'They': 'de',
#  'girl': 'flicka',
#  'woman': 'kvinna',
#  'the man': 'mannen',
#  'the woman': 'kvinnan',
#  'boy': 'pojke',
#  'drink': 'dricker',
#  'water': 'vatten',
#  'newspaper': 'tidning',
#  'read': 'laser',
#  'milk': 'mjolk',
#  'sandwich': 'smorgas',
#  'child': 'barn',
#  'book': 'bok',
#  'menu': 'meny',
#  'letter': 'brev',
#  'have': 'har',
#  'thank you so much': 'tack sa mycket',
#  'love': 'alskar',
#  'speak': 'talar',
#  'not': 'inte',
#  'think': 'tycker',
#  'chicken': 'kyckling',
# ...
